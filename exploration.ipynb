# %%
# %sql
SELECT *
FROM flights_project.bronze.passengers

# %%
# %sql
SELECT * FROM flights_project.silver.passengers_silver
WHERE passenger_id == "P0049"

# %%
# %sql
SELECT *
FROM flights_project.gold.flights_business_join
