# %%
# Defines raw datasets and their specific configurations
main_catalog_name = "flights_project"
checkpoint_volume = "etl_metadata"

flights_data_params = [
    {
        "source_name": "bookings",
        "raw_path": f"/Volumes/{main_catalog_name}/raw/raw_volume/raw_data/bookings/",
        "checkpoint": f"/Volumes/{main_catalog_name}/bronze/{checkpoint_volume}/bookings/checkpoints",
        "target_table": f"{main_catalog_name}.bronze.bookings"
    },
    {
        "source_name": "passengers",
        "raw_path": f"/Volumes/{main_catalog_name}/raw/raw_volume/raw_data/passengers/",
        "checkpoint": f"/Volumes/{main_catalog_name}/bronze/{checkpoint_volume}/passengers/checkpoints",
        "target_table": f"{main_catalog_name}.bronze.passengers"
    },
    {
        "source_name": "flights",
        "raw_path": f"/Volumes/{main_catalog_name}/raw/raw_volume/raw_data/flights/",
        "checkpoint": f"/Volumes/{main_catalog_name}/bronze/{checkpoint_volume}/flights/checkpoints",
        "target_table": f"{main_catalog_name}.bronze.flights"
    },
    {
        "source_name": "airports",
        "raw_path": f"/Volumes/{main_catalog_name}/raw/raw_volume/raw_data/airports/",
        "checkpoint": f"/Volumes/{main_catalog_name}/bronze/{checkpoint_volume}/airports/checkpoints",
        "target_table": f"{main_catalog_name}.bronze.airports"
    }
]

dbutils.jobs.taskValues.set(key="job_params", value=flights_data_params)
